# %%
import matplotlib.pyplot as plt
#import numpy as np

xpoints = x=([0, 10])
ypoints = x=([10, 100])

plt.plot(xpoints, ypoints)
plt.show()

# %%
y = np.array([35, 25, 25, 15,12,13,14])

plt.pie(y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# ### WAP to check weather the word is available in the inputted sentence.

# %%
sentence=input("Wriet your sentence :")
print(sentence)
find=input("write the word which you want to search in above sentence : ")
if (find in sentence):
    print(find," is available in given sentence : ",sentence)
else:
    print(find," is not  available in given sentence : ",sentence)
# Out:
# Wriet your sentence :
#
# write the word which you want to search in above sentence :
#      is available in given sentence :

# %%
b = "Hello, World!"
print(b[-2:-5])
